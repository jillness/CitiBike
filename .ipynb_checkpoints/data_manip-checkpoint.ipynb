# %%
import pandas as pd
from datetime import datetime
from geopy.distance import geodesic

# %%
csv_list = ['../old data/JC-201806-citibike-tripdata.csv', '../old data/JC-201805-citibike-tripdata.csv', '../old data/JC-201804-citibike-tripdata.csv', 
            '../old data/201803_citibikejc_tripdata.csv', '../old data/201802_citibikejc_tripdata.csv', '../old data/201801_citibikejc_tripdata.csv',
            '../old data/JC-201712-citibike-tripdata.csv', '../old data/JC-201711-citibike-tripdata.csv', '../old data/JC-201710-citibike-tripdata.csv', 
            '../old data/JC-201709-citibike-tripdata.csv', '../old data/JC-201708 citibike-tripdata.csv', '../old data/JC-201707-citibike-tripdata.csv',
            '../old data/JC-201706-citibike-tripdata.csv',
           ]

df_list = []

for csv in csv_list:
    
    starttime = []
    stoptime = []
    startdate = []
    stopdate = []

    df = pd.read_csv(csv)
    
    for index, row in df.iterrows():
        old_start_date = row['starttime']
        old_stop_date = row['stoptime']
        
        startdate.append(old_start_date[0:10])
        starttime.append(old_start_date[11:19])
        stopdate.append(old_stop_date[0:10])
        stoptime.append(old_stop_date[11:19])

    df['startdate'] = startdate
    df['stopdate'] = stopdate
    df['starthour'] = starttime
    df['stophour'] = stoptime
    
    df_list.append(df)

# %%
for df in df_list:
    
    distance = []
    
    for index, row in df.iterrows():
        start = row['start station latitude'], row['start station longitude']
        end = row['end station latitude'], row['end station longitude']
        distance.append(geodesic(start, end).miles)
        
    df['distance between stations (mi)'] = distance

# %%
df = pd.concat(df_list)
df = df.drop(['end station id', 'start station id', 'usertype', 'bikeid', 'name_localizedValue0', 'birth year', 'gender'], axis=1)
df = df.reset_index(drop=True)

# %%
[june2018_df, may2018_df, april2018_df, 
 march2018_df, feb2018_df, jan2018_df, 
 dec2017_df, nov2017_df, oct2017_df, 
 sep2017_df, aug2017_df, july2017_df, june2017_df] = df_list

# %%
len(df)
# Out:
# 352539

# %%
df.head(-10)
# Out:
#         distance between stations (mi)  end station latitude  \
# 0                             0.504560             40.714584
# 1                             0.374889             40.712419
# 2                             0.757575             40.727224
# 3                             0.374889             40.712419
# 4                             0.966462             40.727596
# 5                             0.374889             40.712419
# 6                             0.398911             40.716490
# 7                             0.556987             40.719586
# 8                             0.287536             40.712774
# 9                             1.900129             40.725340
# 10                            0.145091             40.714145
# 11                            0.374889             40.712419
# 12                            0.556987             40.719586
# 13                            0.374889             40.712419
# 14                            0.000000             40.716247
# 15                            0.000000             40.716247
# 16                            0.000000             40.716247
# 17                            1.115343             40.726012
# 18                            0.865295             40.728745
# 19                            0.413956             40.721124
# 20                            0.764896             40.718489
# 21                            0.413956             40.721124
# 22                            0.000000             40.716247
# 23                            0.000000             40.716247
# 24                            0.321258             40.718355
# 25                            0.000000             40.716247
# 26                            2.014373             40.744319
# 27                            0.413956             40.721124
# 28                            1.880125             40.730743
# 29                            0.374889             40.712419
# ...                                ...                   ...
# 352499                        0.374889             40.712419
# 352500                        0.477422             40.721124
# 352501                        0.214238             40.721525
# 352502                        0.383776             40.721124
# 352503                        0.383776             40.721124
# 352504                        0.307568             40.727596
# 352505                        0.404538             40.714145
# 352506                        1.983053             40.752559
# 352507                        0.584952             40.719586
# 352508                        0.856394             40.719586
# 352509                        0.856394             40.719586
# 352510                        0.416431             40.727596
# 352512       2017-06-30 22:51:18           280
# 352513       2017-06-30 22:55:57           213
# 352514       2017-06-30 22:56:23           225
# 352515       2017-06-30 23:01:49           548
# 352516       2017-06-30 22:57:50           228
# 352517       2017-06-30 23:05:20           249
# 352518       2017-06-30 23:04:12           134
# 352519       2017-06-30 23:10:44           444
# 352520       2017-06-30 23:09:28           360
# 352521       2017-06-30 23:11:24           304
# 352522       2017-06-30 23:22:19           859
# 352523       2017-06-30 23:12:44           252
# 352524       2017-06-30 23:12:44           241
# 352525       2017-06-30 23:16:17           406
# 352526       2017-06-30 23:13:06           191
# 352527       2017-06-30 23:27:37           470
# 352528       2017-07-01 00:03:19          2436
#
# [352529 rows x 14 columns]

# %%
# df.to_excel('CitiBikeClean.xlsx')

# %%
month_df = [june2018_df, may2018_df, april2018_df, 
             march2018_df, feb2018_df, jan2018_df, 
             dec2017_df, nov2017_df, oct2017_df, 
             sep2017_df, aug2017_df, july2017_df, june2017_df]

for df in month_df:
    print(len(df))
# Out:
# 40937
# 34455
# 23634
# 17109
# 15104
# 12677
# 15898
# 23582
# 34919
# 33119
# 35472
# 33573
# 32060

# %%
df_clean = df.dropna(axis=0, thresh = 1,
                     subset=['end station latitude', 'end station longitude', 
                             'start station latitude', 'start station longitude'])

# %%
df.dtypes
# Out:
# distance between stations (mi)    float64
# end station latitude              float64
# end station longitude             float64
# end station name                   object
# start station latitude            float64
# start station longitude           float64
# start station name                 object
# startdate                          object
# starthour                          object
# starttime                          object
# stopdate                           object
# stophour                           object
# stoptime                           object
# tripduration                        int64
# dtype: object

# %%
print(len(df), len(df_clean))
# Out:
# 352539 352539

# %%
# df_clean.to_excel('CitiBikeCLEANER.xlsx')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-44437c7a40d5> in <module>()
# ----> 1 df_clean.to_excel('CitiBikeCLEANER.xlsx')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    1422         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    1423                         startcol=startcol, freeze_panes=freeze_panes,
# -> 1424                         engine=engine)
#    1425
#    1426     def to_stata(self, fname, convert_dates=None, write_index=True,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     626         writer.write_cells(formatted_cells, sheet_name,
#     627                            startrow=startrow, startcol=startcol,
# --> 628                            freeze_panes=freeze_panes)
#     629         if need_save:
#     630             writer.save()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/excel.py in write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#    1598                 wks.write(startrow + cell.row,
#    1599                           startcol + cell.col,
# -> 1600                           val, style)
#    1601
#    1602     def _convert_to_style(self, style_dict, num_format_str=None):
#
# ~/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py in cell_wrapper(self, *args, **kwargs)
#      63             args = new_args
#      64
# ---> 65         return method(self, *args, **kwargs)
#      66
#      67     return cell_wrapper
#
# ~/anaconda3/lib/python3.6/site-packages/xlsxwriter/worksheet.py in write(self, row, col, *args)
#     404                 return self.write_url(row, col, *args)
#     405
# --> 406             elif self.strings_to_urls and re.match('(in|ex)ternal:', token):
#     407                 return self.write_url(row, col, *args)
#     408
#
# ~/anaconda3/lib/python3.6/re.py in match(pattern, string, flags)
#     167 # public interface
#     168
# --> 169 def match(pattern, string, flags=0):
#     170     """Try to apply the pattern at the start of the string, returning
#     171     a match object, or None if no match was found."""
#
# KeyboardInterrupt:

# %%
df_clean.head(-50)
